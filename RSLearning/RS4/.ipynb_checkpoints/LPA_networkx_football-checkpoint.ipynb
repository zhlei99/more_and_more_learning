# %%
import networkx as nx
from networkx.algorithms import community
import matplotlib.pyplot as plt

# %%
G = nx.read_gml('../../datasets/LPA/football.gml')

# %%
nx.draw(G, with_labels =True)
# Out:
# /Users/zhaolei/opt/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
communities = list(community.)

# %%
communities = list(community.label_propagation_communities(G))

# %%
print(communities)
# Out:
# [{'BowlingGreenState', 'Ohio', 'MiamiOhio', 'Akron', 'Marshall', 'Connecticut', 'Buffalo', 'Kent'}, {'MiamiFlorida', 'BostonCollege', 'Syracuse', 'Navy', 'Rutgers', 'Temple', 'NotreDame', 'WestVirginia', 'VirginiaTech', 'Pittsburgh'}, {'NevadaLasVegas', 'Wyoming', 'NewMexico', 'ColoradoState', 'BrighamYoung', 'AirForce', 'SanDiegoState', 'Utah'}, {'PennState', 'Purdue', 'Indiana', 'MichiganState', 'Northwestern', 'Illinois', 'Wisconsin', 'OhioState', 'Iowa', 'Minnesota', 'Michigan'}, {'TexasA&M', 'IowaState', 'Nebraska', 'Kansas', 'Oklahoma', 'OklahomaState', 'Missouri', 'KansasState', 'Texas', 'Baylor', 'Colorado', 'TexasTech'}, {'NorthCarolinaState', 'FloridaState', 'NorthCarolina', 'GeorgiaTech', 'WakeForest', 'Clemson', 'Maryland', 'Virginia', 'Duke'}, {'UtahState', 'NewMexicoState', 'OregonState', 'Oregon', 'BoiseState', 'Stanford', 'WashingtonState', 'SouthernCalifornia', 'California', 'Idaho', 'ArkansasState', 'ArizonaState', 'UCLA', 'Arizona', 'NorthTexas', 'Washington'}, {'Houston', 'AlabamaBirmingham', 'Cincinnati', 'SouthernMississippi', 'EastCarolina', 'Tulane', 'Memphis', 'Louisville', 'Army'}, {'Auburn', 'MississippiState', 'Mississippi', 'CentralFlorida', 'LouisianaTech', 'Arkansas', 'Kentucky', 'Tennessee', 'Georgia', 'Florida', 'LouisianaMonroe', 'LouisianaState', 'Vanderbilt', 'LouisianaLafayette', 'SouthCarolina', 'Alabama', 'MiddleTennesseeState'}, {'SouthernMethodist', 'Rice', 'SanJoseState', 'Hawaii', 'TexasElPaso', 'TexasChristian', 'FresnoState', 'Tulsa', 'Nevada'}, {'NorthernIllinois', 'CentralMichigan', 'BallState', 'Toledo', 'EasternMichigan', 'WesternMichigan'}]

# %%
len(communities)
# Out:
# 11
