# %% [markdown]
# # AVL树

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ## AVL树的遍历、查找操作与二叉搜索树相同

# %%
clsaa Node(object):
    def __init__(self, key):
        self.key = key
        self.left = None
        self.right = None
        self.parent = None
        
        self.height = 0
        
class AVLTree(object):
